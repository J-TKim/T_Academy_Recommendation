# %% [markdown]
# Upgrade mlxtend to use fpgrowth

# %%
pip install mlxtend --upgrade --no-deps
# Out:
# Requirement already up-to-date: mlxtend in /usr/local/lib/python3.7/dist-packages (0.18.0)

# %%
import mlxtend
import numpy as np
import pandas as pd

# %%
# 데이터셋을 생성
# 우유, 기저귀, 쥬스, 맥주, 양상추
data = np.array([
    ['우유', '기저귀', '쥬스'],
    ['양상추', '기저귀', '맥주'],
    ['우유', '양상추', '기저귀', '맥주'],
    ['양상추', '맥주']
])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   import sys

# %% [markdown]
# # Apriori 알고리즘

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     쥬스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %%
te_ary
# Out:
# array([[ True, False, False,  True,  True],
#        [ True,  True,  True, False, False],
#        [ True,  True,  True,  True, False],
#        [False,  True,  True, False, False]])

# %%
te.columns_
# Out:
# ['기저귀', '맥주', '양상추', '우유', '쥬스']

# %%
# %%time
from mlxtend.frequent_patterns import apriori

print(apriori(df, min_support=0.5, use_colnames=True))
# Out:
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.75            (맥주)
# 2     0.75           (양상추)
# 3     0.50            (우유)
# 4     0.50       (맥주, 기저귀)
# 5     0.50      (양상추, 기저귀)
# 6     0.50       (기저귀, 우유)
# 7     0.75       (맥주, 양상추)
# 8     0.50  (맥주, 양상추, 기저귀)
# CPU times: user 25.8 ms, sys: 427 µs, total: 26.2 ms
# Wall time: 29.8 ms

# %% [markdown]
# # FP-Growth 알고리즘

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     쥬스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %%
# %%time
from mlxtend.frequent_patterns import fpgrowth

print(fpgrowth(df, min_support=0.5, use_colnames=True))
# Out:
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.50            (우유)
# 2     0.75           (양상추)
# 3     0.75            (맥주)
# 4     0.50       (맥주, 기저귀)
# 5     0.50      (양상추, 기저귀)
# 6     0.50  (맥주, 양상추, 기저귀)
# 7     0.50       (기저귀, 우유)
# 8     0.75       (맥주, 양상추)
# CPU times: user 12.1 ms, sys: 14 µs, total: 12.1 ms
# Wall time: 11.7 ms

# %% [markdown]
# ### apriori에서 신뢰도나 향상도를 데이터프레임에서 확인

# %%
from mlxtend.frequent_patterns import association_rules

association = fpgrowth(df, min_support=0.1, use_colnames=True)
association_rules(association, metric='confidence', min_threshold=0.5, support_only=False)
# Out:
#        antecedents     consequents  ...  leverage  conviction
# 0             (맥주)           (기저귀)  ...   -0.0625        0.75
# 1            (기저귀)            (맥주)  ...   -0.0625        0.75
# 2            (양상추)           (기저귀)  ...   -0.0625        0.75
# 3            (기저귀)           (양상추)  ...   -0.0625        0.75
# 4        (맥주, 양상추)           (기저귀)  ...   -0.0625        0.75
# 5        (맥주, 기저귀)           (양상추)  ...    0.1250         inf
# 6       (양상추, 기저귀)            (맥주)  ...    0.1250         inf
# 7             (맥주)      (양상추, 기저귀)  ...    0.1250        1.50
# 8            (양상추)       (맥주, 기저귀)  ...    0.1250        1.50
# 9            (기저귀)       (맥주, 양상추)  ...   -0.0625        0.75
# 10           (기저귀)            (우유)  ...    0.1250        1.50
# 11            (우유)           (기저귀)  ...    0.1250         inf
# 12            (우유)            (맥주)  ...   -0.1250        0.50
# 13            (우유)           (양상추)  ...   -0.1250        0.50
# 14       (맥주, 기저귀)            (우유)  ...    0.0000        1.00
# 15        (맥주, 우유)           (기저귀)  ...    0.0625         inf
# 16       (기저귀, 우유)            (맥주)  ...   -0.1250        0.50
# 17            (우유)       (맥주, 기저귀)  ...    0.0000        1.00
# 18      (양상추, 기저귀)            (우유)  ...    0.0000        1.00
# 19       (양상추, 우유)           (기저귀)  ...    0.0625         inf
# 20       (기저귀, 우유)           (양상추)  ...   -0.1250        0.50
# 21            (우유)      (양상추, 기저귀)  ...    0.0000        1.00
# 22        (맥주, 우유)           (양상추)  ...    0.0625         inf
# 23       (양상추, 우유)            (맥주)  ...    0.0625         inf
# 24            (우유)       (맥주, 양상추)  ...   -0.1250        0.50
# 25  (맥주, 양상추, 기저귀)            (우유)  ...    0.0000        1.00
# 26   (맥주, 양상추, 우유)           (기저귀)  ...    0.0625         inf
# 27   (맥주, 기저귀, 우유)           (양상추)  ...    0.0625         inf
# 28  (양상추, 우유, 기저귀)            (맥주)  ...    0.0625         inf
# 29       (맥주, 기저귀)       (양상추, 우유)  ...    0.1250        1.50
# 30        (맥주, 우유)      (양상추, 기저귀)  ...    0.1250         inf
# 31      (양상추, 기저귀)        (맥주, 우유)  ...    0.1250        1.50
# 32       (양상추, 우유)       (맥주, 기저귀)  ...    0.1250         inf
# 33       (기저귀, 우유)       (맥주, 양상추)  ...   -0.1250        0.50
# 34            (우유)  (맥주, 양상추, 기저귀)  ...    0.0000        1.00
# 35            (우유)            (쥬스)  ...    0.1250        1.50
# 36            (쥬스)            (우유)  ...    0.1250         inf
# 37            (쥬스)           (기저귀)  ...    0.0625         inf
# 38       (기저귀, 우유)            (쥬스)  ...    0.1250        1.50
# 39       (기저귀, 쥬스)            (우유)  ...    0.1250         inf
# 40        (우유, 쥬스)           (기저귀)  ...    0.0625         inf
# 41            (우유)       (기저귀, 쥬스)  ...    0.1250        1.50
# 42            (쥬스)       (기저귀, 우유)  ...    0.1250         inf
# 43            (맥주)           (양상추)  ...    0.1875         inf
# 44           (양상추)            (맥주)  ...    0.1875         inf
#
# [45 rows x 9 columns]
